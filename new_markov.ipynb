# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# 加载数据
file_path = '~/MCM/tennis2.csv'
data = pd.read_csv(file_path)

# 分析所有比赛
match_ids = data['match_id'].unique()

# 假设data是包含比赛数据的DataFrame，其中包括'match_id', 'server', 和'point_victor'列

# 定义扩展的状态，考虑发球方和得分点的获胜者
extended_states = [
    'P1_serve_win', 'P1_serve_lose',
    'P2_serve_win', 'P2_serve_lose'
]

# 初始化每场比赛的转移概率矩阵
match_transition_probabilities = {}

# 遍历每场比赛
for match_id in data['match_id'].unique():
    match_data = data[data['match_id'] == match_id]

    # 初始化转移计数矩阵
    transition_counts = pd.DataFrame(0, index=extended_states, columns=extended_states)

    # 遍历比赛数据
    for i in range(1, len(match_data)):
        prev_point = match_data.iloc[i-1]
        curr_point = match_data.iloc[i]

        # 确定前一个点和当前点的状态
        prev_state = 'P{}_serve_{}'.format(prev_point['server'], 'win' if prev_point['point_victor'] == prev_point['server'] else 'lose')
        curr_state = 'P{}_serve_{}'.format(curr_point['server'], 'win' if curr_point['point_victor'] == curr_point['server'] else 'lose')

        # 更新转移计数
        transition_counts.loc[prev_state, curr_state] += 1

    # 计算并存储每场比赛的转移概率矩阵
    transition_probabilities = transition_counts.div(transition_counts.sum(axis=1), axis=0)
    match_transition_probabilities[match_id] = transition_probabilities

# 打印每场比赛的转移概率矩阵
for match_id, probabilities in match_transition_probabilities.items():
    print(f"Match ID: {match_id}")
    print("转换概率矩阵:")
    print(probabilities)
    print("\n")
    # 可视化：以转换概率矩阵为例，为每场比赛生成一个简单的可视化
    sns.heatmap(transition_probabilities, annot=True, cmap='coolwarm')
    plt.title(f"Transition Probabilities for Match {match_id}")
    plt.show()
import pandas as  pd
import numpy as np

def simulate_scenario(transition_probabilities, scenario_func, num_simulations=1000):
    """
    通用场景模拟函数，计算并返回选手获胜的概率。
    参数:
    - transition_probabilities: 转移概率矩阵
    - scenario_func: 场景模拟函数，如 simulate_game, simulate_tiebreak, simulate_set 或 simulate_match
    - num_simulations: 模拟次数，默认为1000
    返回:
    - 选手1和选手2获胜的概率
    """
    outcomes = {'P1_win': 0, 'P2_win': 0}
    for _ in range(num_simulations):
        winner = scenario_func(transition_probabilities)
        outcomes[winner] += 1
    p1_win_prob = outcomes['P1_win'] / num_simulations
    p2_win_prob = outcomes['P2_win'] / num_simulations
    return p1_win_prob, p2_win_prob

def simulate_point(transition_probabilities):
    """模拟得分点，返回获胜选手。"""
    return np.random.choice(['P1_win', 'P2_win'], p=[transition_probabilities['P1_win'], transition_probabilities['P2_win']])
# 定义模拟一局、模拟抢七局、模拟一个盘和模拟整场比赛的函数
def simulate_game(transition_probabilities):
    # 模拟一局比赛的逻辑
    score = {'P1_win': 0, 'P2_win': 0}
    while max(score.values()) < 4 or abs(score['P1_win'] - score['P2_win']) < 2:
        point_winner = simulate_point(transition_probabilities)
        score[point_winner] += 1
    return 'P1_win' if score['P1_win'] > score['P2_win'] else 'P2_win'

def simulate_tiebreak(transition_probabilities):
    # 模拟抢七局的逻辑
    score = {'P1_win': 0, 'P2_win': 0}
    while max(score.values()) < 7 or abs(score['P1_win'] - score['P2_win']) < 2:
        point_winner = simulate_point(transition_probabilities)
        score[point_winner] += 1
    return 'P1_win' if score['P1_win'] > score['P2_win'] else 'P2_win'

def simulate_set(transition_probabilities):
    # 模拟一个盘的逻辑
    games_won = {'P1_win': 0, 'P2_win': 0}
    while max(games_won.values()) < 6 or abs(games_won['P1_win'] - games_won['P2_win']) < 2:
        if games_won['P1_win'] == 6 and games_won['P2_win'] == 6:
            tiebreak_winner = simulate_tiebreak(transition_probabilities)
            games_won[tiebreak_winner] += 1
            break
        game_winner = simulate_game(transition_probabilities)
        games_won[game_winner] += 1
    return 'P1_win' if games_won['P1_win'] > games_won['P2_win'] else 'P2_win'

def simulate_match(transition_probabilities, best_of=5):
    # 模拟整场比赛的逻辑
    sets_won = {'P1_win': 0, 'P2_win': 0}
    for _ in range(best_of):
        set_winner = simulate_set(transition_probabilities)
        sets_won[set_winner] += 1
        if sets_won[set_winner] > best_of // 2:
            break
    return 'P1_win' if sets_won['P1_win'] > sets_won['P2_win'] else 'P2_win'

# 为每场比赛计算转移概率矩阵并模拟获胜概率
for match_id in match_ids:
    # 假设已经计算了该场比赛的转移概率矩阵 transition_probabilities
    transition_probabilities = {'P1_win': 0.6, 'P2_win': 0.4}  # 示例转移概率

    # 模拟并输出赢得一局比赛的概率
    p1_win_prob, p2_win_prob = simulate_scenario(transition_probabilities, simulate_game)
    print(f"Match ID {match_id}: 赢得一局比赛的概率 — P1: {p1_win_prob}, P2: {p2_win_prob}")

    # 模拟并输出赢得抢七局的概率
    p1_win_prob, p2_win_prob = simulate_scenario(transition_probabilities, simulate_tiebreak)
    print(f"Match ID {match_id}: 赢得抢七局的概率 — P1: {p1_win_prob}, P2: {p2_win_prob}")

    # 模拟并输出赢得一个盘的概率
    p1_win_prob, p2_win_prob = simulate_scenario(transition_probabilities, simulate_set)
    print(f"Match ID {match_id}: 赢得一个盘的概率 — P1: {p1_win_prob}, P2: {p2_win_prob}")

    # 模拟并输出赢得整场比赛的概率
    p1_win_prob, p2_win_prob = simulate_scenario(transition_probabilities, lambda tp: simulate_match(tp, best_of=5))
    print(f"Match ID {match_id}: 赢得整场比赛的概率 — P1: {p1_win_prob}, P2: {p2_win_prob}")
# Out:
# Match ID: 2023-wimbledon-1301
# 转换概率矩阵:
#                P1_serve_win  P1_serve_lose  P2_serve_win  P2_serve_lose
# P1_serve_win       0.495050       0.287129      0.148515       0.069307
# P1_serve_lose      0.673469       0.285714      0.040816       0.000000
# P2_serve_win       0.161290       0.043011      0.483871       0.311828
# P2_serve_lose      0.071429       0.017857      0.553571       0.357143
# Match ID: 2023-wimbledon-1302
# 转换概率矩阵:
#                P1_serve_win  P1_serve_lose  P2_serve_win  P2_serve_lose
# P1_serve_win       0.600000       0.128571      0.200000       0.071429
# P1_serve_lose      0.578947       0.263158      0.052632       0.105263
# P2_serve_win       0.207317       0.048780      0.548780       0.195122
# P2_serve_lose      0.000000       0.034483      0.793103       0.172414
# Match ID: 2023-wimbledon-1303
# 转换概率矩阵:
#                P1_serve_win  P1_serve_lose  P2_serve_win  P2_serve_lose
# P1_serve_win       0
# 转换概率矩阵:
#                P1_serve_win  P1_serve_lose  P2_serve_win  P2_serve_lose
# P1_serve_win       0.594203       0.144928      0.173913       0.086957
# P1_serve_lose      0.727273       0.272727      0.000000       0.000000
# P2_serve_win       0.156250       0.062500      0.531250       0.250000
# P2_serve_lose      0.060606       0.060606      0.545455       0.333333
# Match ID: 2023-wimbledon-1502
# 转换概率矩阵:
#                P1_serve_win  P1_serve_lose  P2_serve_win  P2_serve_lose
# P1_serve_win       0.597826       0.173913      0.152174       0.076087
# P1_serve_lose      0.500000       0.375000      0.093750       0.031250
# P2_serve_win       0.168317       0.029703      0.485149       0.316832
# P2_serve_lose      0.070175       0.017544      0.596491       0.315789
# Match ID: 2023-wimbledon-1503
# 转换概率矩阵:
#                P1_serve_win  P1_serve_lose  P2_serve_win  P2_serve_lose
# P1_serve_win       0.569231       0.200000      0.092308       0.138462
# P1_serve_lose      0.608696       0.304348      0.086957       0.000000
# P2_serve_win       0.145161       0.048387      0.532258       0.274194
# P2_serve_lose      0.119048       0.000000      0.476190       0.404762
# Match ID: 2023-wimbledon-1504
# 转换概率矩阵:
#                P1_serve_win  P1_serve_lose  P2_serve_win  P2_serve_lose
# P1_serve_win       0.444444       0.349206      0.126984       0.079365
# P1_serve_lose      0.589744       0.307692      0.051282       0.051282
# P2_serve_win       0.135802       0.074074      0.567901       0.222222
# P2_serve_lose      0.030303       0.000000      0.727273       0.242424
# Match ID: 2023-wimbledon-1601
# 转换概率矩阵:
#                P1_serve_win  P1_serve_lose  P2_serve_win  P2_serve_lose
# P1_serve_win       0.547170       0.245283      0.094340       0.113208
# P1_serve_lose      0.600000       0.320000      0.000000       0.080000
# P2_serve_win       0.093023       0.069767      0.488372       0.348837
# P2_serve_lose      0.135135       0.027027      0.459459       0.378378
# Match ID: 2023-wimbledon-1602
# 转换概率矩阵:
#                P1_serve_win  P1_serve_lose  P2_serve_win  P2_serve_lose
# P1_serve_win       0.508197       0.262295      0.147541       0.081967
# P1_serve_lose      0.620690       0.241379      0.103448       0.034483
# P2_serve_win       0.157895       0.078947      0.473684       0.289474
# P2_serve_lose      0.000000       0.000000      0.800000       0.200000
# Match ID: 2023-wimbledon-1701
# 转换概率矩阵:
#                P1_serve_win  P1_serve_lose  P2_serve_win  P2_serve_lose
# P1_serve_win       0.516129       0.279570      0.107527       0.096774
# P1_serve_lose      0.607143       0.285714      0.089286       0.017857
# P2_serve_win       0.090909       0.100000      0.454545       0.354545
# P2_serve_lose      0.027027       0.040541      0.594595       0.337838
# Match ID 2023-wimbledon-1301: 赢得一局比赛的概率 — P1: 0.745, P2: 0.255
# Match ID 2023-wimbledon-1301: 赢得抢七局的概率 — P1: 0.775, P2: 0.225
# Match ID 2023-wimbledon-1301: 赢得一个盘的概率 — P1: 0.96, P2: 0.04
# Match ID 2023-wimbledon-1301: 赢得整场比赛的概率 — P1: 0.999, P2: 0.001
# Match ID 2023-wimbledon-1302: 赢得一局比赛的概率 — P1: 0.741, P2: 0.259
# Match ID 2023-wimbledon-1302: 赢得抢七局的概率 — P1: 0.776, P2: 0.224
# Match ID 2023-wimbledon-1302: 赢得一个盘的概率 — P1: 0.973, P2: 0.027
# Match ID 2023-wimbledon-1302: 赢得整场比赛的概率 — P1: 1.0, P2: 0.0
# Match ID 2023-wimbledon-1303: 赢得一局比赛的概率 — P1: 0.747, P2: 0.253
# Match ID 2023-wimbledon-1303: 赢得抢七局的概率 — P1: 0.756, P2: 0.244
# Match ID 2023-wimbledon-1303: 赢得一个盘的概率 — P1: 0.969, P2: 0.031
# Match ID 2023-wimbledon-1303: 赢得整场比赛的概率 — P1: 0.999, P2: 0.001
# Match ID 2023-wimbledon-1304: 赢得一局比赛的概率 — P1: 0.74, P2: 0.26
# Match ID 2023-wimbledon-1304: 赢得抢七局的概率 — P1: 0.763, P2: 0.237
# Match ID 2023-wimbledon-1304: 赢得一个盘的概率 — P1: 0.959, P2: 0.041
# Match ID 2023-wimbledon-1304: 赢得整场比赛的概率 — P1: 1.0, P2: 0.0
# Match ID 2023-wimbledon-
 赢得整场比赛的概率 — P1: 1.0, P2: 0.0
# Match ID 2023-wimbledon-1407: 赢得一局比赛的概率 — P1: 0.736, P2: 0.264
# Match ID 2023-wimbledon-1407: 赢得抢七局的概率 — P1: 0.787, P2: 0.213
# Match ID 2023-wimbledon-1407: 赢得一个盘的概率 — P1: 0.964, P2: 0.036
# Match ID 2023-wimbledon-1407: 赢得整场比赛的概率 — P1: 1.0, P2: 0.0
# Match ID 2023-wimbledon-1408: 赢得一局比赛的概率 — P1: 0.709, P2: 0.291
# Match ID 2023-wimbledon-1408: 赢得抢七局的概率 — P1: 0.768, P2: 0.232
# Match ID 2023-wimbledon-1408: 赢得一个盘的概率 — P1: 0.97, P2: 0.03
# Match ID 2023-wimbledon-1408: 赢得整场比赛的概率 — P1: 1.0, P2: 0.0
# Match ID 2023-wimbledon-1501: 赢得一局比赛的概率 — P1: 0.749, P2: 0.251
# Match ID 2023-wimbledon-1501: 赢得抢七局的概率 — P1: 0.791, P2: 0.209
# Match ID 2023-wimbledon-1501: 赢得一个盘的概率 — P1: 0.962, P2: 0.038
# Match ID 2023-wimbledon-1501: 赢得整场比赛的概率 — P1: 1.0, P2: 0.0
# Match ID 2023-wimbledon-1502: 赢得一局比赛的概率 — P1: 0.754, P2: 0.246
# Match ID 2023-wimbledon-1502: 赢得抢七局的概率 — P1: 0.781, P2: 0.219
# Match ID 2023-wimbledon-1502: 赢得一个盘的概率 — P1: 0.964, P2: 0.036
# Match ID 2023-wimbledon-1502: 赢得整场比赛的概率 — P1: 1.0, P2: 0.0
# Match ID 2023-wimbledon-1503: 赢得一局比赛的概率 — P1: 0.73, P2: 0.27
# Match ID 2023-wimbledon-1503: 赢得抢七局的概率 — P1: 0.796, P2: 0.204
# Match ID 2023-wimbledon-1503: 赢得一个盘的概率 — P1: 0.971, P2: 0.029
# Match ID 2023-wimbledon-1503: 赢得整场比赛的概率 — P1: 0.999, P2: 0.001
# Match ID 2023-wimbledon-1504: 赢得一局比赛的概率 — P1: 0.727, P2: 0.273
# Match ID 2023-wimbledon-1504: 赢得抢七局的概率 — P1: 0.784, P2: 0.216
# Match ID 2023-wimbledon-1504: 赢得一个盘的概率 — P1: 0.958, P2: 0.042
# Match ID 2023-wimbledon-1504: 赢得整场比赛的概率 — P1: 0.998, P2: 0.002
# Match ID 2023-wimbledon-1601: 赢得一局比赛的概率 — P1: 0.713, P2: 0.287
# Match ID 2023-wimbledon-1601: 赢得抢七局的概率 — P1: 0.775, P2: 0.225
# Match ID 2023-wimbledon-1601: 赢得一个盘的概率 — P1: 0.97, P2: 0.03
# Match ID 2023-wimbledon-1601: 赢得整场比赛的概率 — P1: 1.0, P2: 0.0
# Match ID 2023-wimbledon-1602: 赢得一局比赛的概率 — P1: 0.724, P2: 0.276
# Match ID 2023-wimbledon-1602: 赢得抢七局的概率 — P1: 0.782, P2: 0.218
# Match ID 2023-wimbledon-1602: 赢得一个盘的概率 — P1: 0.959, P2: 0.041
# Match ID 2023-wimbledon-1602: 赢得整场比赛的概率 — P1: 1.0, P2: 0.0
# Match ID 2023-wimbledon-1701: 赢得一局比赛的概率 — P1: 0.749, P2: 0.251
# Match ID 2023-wimbledon-1701: 赢得抢七局的概率 — P1: 0.81, P2: 0.19
# Match ID 2023-wimbledon-1701: 赢得一个盘的概率 — P1: 0.961, P2: 0.039
# Match ID 2023-wimbledon-1701: 赢得整场比赛的概率 — P1: 0.999, P2: 0.001
